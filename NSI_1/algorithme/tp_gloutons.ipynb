# %% [markdown]
# # 🐉 TP : Les Algorithmes Gloutons
# ## 🌌 Thème : La Quête du Trésor
#
# ---
#
# ### 📜 Le Scénario
# Vous êtes un aventurier parcourant les royaumes pour amasser des richesses. Durant votre périple, vous êtes confronté à deux épreuves récurrentes : gérer votre monnaie lors de vos achats dans les villages, et optimiser l'espace dans votre besace lorsque vous pillez un donjon.
#
# Pour vous faciliter la vie, vous allez coder une intelligence (un **Algorithme Glouton**) qui prendra toujours la décision qui semble la meilleure sur le moment.
#
# **Rappel de la règle d'or :** L'algorithme glouton fait le choix optimal *localement*, étape par étape, et ne revient **jamais** en arrière.
#
# ---

# %% [markdown]
# ## 🪙 Mission 1 : La Boutique du Village (Rendu de Monnaie)
#
# Vous devez acheter des provisions, et la marchande doit vous rendre la monnaie. Elle veut se débarrasser du moins de pièces possible. Son système monétaire est composé de pièces et de billets en écus.
#
# ### ✏️ Exercice 1 — L'Instinct du Caissier
# Complétez la fonction ci-dessous en utilisant la stratégie gloutonne : **Rendre toujours la pièce/billet de la plus grande valeur possible sans dépasser la somme à rendre.**

# %%
def rendu_monnaie(somme_a_rendre, systeme_monnaie):
    """
    Calcule les pièces à rendre en utilisant un algorithme glouton.
    Retourne : Liste des pièces/billets.
    """
    pieces_rendues = []
    
    # Parcours des pièces/billets disponibles (de la plus grande à la plus petite valeur)
    for piece in systeme_monnaie:
        
        # Tant que la pièce peut être rendue (sans rendre trop d'argent)
        while somme_a_rendre >= ... : # <-- Complétez la condition
            
            # 1. Ajouter la pièce à la liste des pièces rendues
            # ... VOTRE CODE ICI ...
            
            # 2. Soustraire la valeur de cette pièce à la somme qu'il reste à rendre
            # ... VOTRE CODE ICI ...
            
    return pieces_rendues

# --- Zone de Test ---
systeme_royaume = [500, 200, 100, 50, 20, 10, 5, 2, 1] # Du plus grand au plus petit

rendu = rendu_monnaie(68, systeme_royaume)
print(f"Pour 68 écus, on rend : {rendu} (Total: {len(rendu)} pièces)")

# Assertions pour vérifier votre code
assert rendu_monnaie(14, systeme_royaume) == [10, 2, 2]
assert rendu_monnaie(68, systeme_royaume) == [50, 10, 5, 2, 1]

# %% [markdown]
# ## ⚠️ Mission 2 : Le Piège de l'Illusion (Les Limites)
#
# Vous arrivez dans le village des Gobelins. Leur système monétaire est très étrange : ils utilisent des pièces de **4**, **3** et **1** écu.
# Vous devez rendre **6 écus**.

# %%
systeme_gobelin = [4, 3, 1]
rendu_gobelin = rendu_monnaie(6, systeme_gobelin)

print(f"Le glouton rend pour 6 écus : {rendu_gobelin}")
print(f"Nombre de pièces utilisées par le glouton : {len(rendu_gobelin)}")

# %% [markdown]
# ### 🧠 Analyse Critique
#
# **Question 1 :** Quelle est la combinaison optimale (celle qui utilise le moins de pièces possible) pour rendre 6 écus chez les Gobelins ? Pourquoi notre fonction gloutonne a-t-elle échoué à trouver cette combinaison ?

# %% [markdown]
# ---
# ## 🎒 Mission 3 : Le Butin du Donjon (Le Sac à Dos)
#
# Vous avez terrassé le gardien du donjon ! Une montagne de trésors s'offre à vous. Hélas, votre besace magique ne peut supporter qu'un poids maximal de **10 kg**.
#
# Voici les objets à disposition :

# %%
tresor = [
    {"nom": "Lingot d'or", "poids": 8, "valeur": 8000},
    {"nom": "Joyau A", "poids": 5, "valeur": 5000},
    {"nom": "Joyau B", "poids": 5, "valeur": 5000},
    {"nom": "Couronne", "poids": 2, "valeur": 4000},
    {"nom": "Coupe en argent", "poids": 3, "valeur": 1500}
]

capacite_besace = 10

# %% [markdown]
# ### ✏️ Exercice 2 — Préparer la Stratégie
#
# L'approche gloutonne a besoin d'une **fonction d'évaluation** pour trier les objets.
# Préparez les 3 tris possibles en utilisant la fonction `sorted()` de Python.

# %%
# 1. Tri par valeur (le plus cher d'abord)
tresor_tri_valeur = sorted(tresor, key=lambda x: x["valeur"], reverse=True)

# 2. À FAIRE : Tri par poids croissant (le plus léger d'abord)
# tresor_tri_poids = ...

# 3. À FAIRE : Tri par ratio (valeur / poids) décroissant
# tresor_tri_ratio = ...

# %% [markdown]
# ## 💎 Mission 4 : L'Épreuve du Choix
#
# Maintenant que les listes sont prêtes, implémentons l'algorithme qui remplit le sac !
#
# ### ✏️ Exercice 3 — Implémenter le remplissage
# Complétez la fonction `remplir_besace`.

# %%
def remplir_besace(objets_tries, capacite_max):
    """
    Parcourt les objets et les ajoute si la capacité restante le permet.
    Retourne : (sac, poids_total, valeur_totale)
    """
    sac = []
    poids_actuel = 0
    valeur_totale = 0
    
    # VOTRE CODE ICI
    
    
    return sac, poids_actuel, valeur_totale

# %% [markdown]
# ### 📊 Test des Stratégies
# Exécutez cette cellule une fois vos fonctions prêtes pour voir quelle stratégie est la meilleure !

# %%
print("--- Stratégie : Le Plus Cher ---")
# sac1, p1, v1 = remplir_besace(tresor_tri_valeur, capacite_besace)
# print(f"Butin : {v1} écus pour {p1} kg. Objets : {[o['nom'] for o in sac1]}\n")

print("--- Stratégie : Le Plus Léger ---")
# sac2, p2, v2 = remplir_besace(tresor_tri_poids, capacite_besace)
# print(f"Butin : {v2} écus pour {p2} kg. Objets : {[o['nom'] for o in sac2]}\n")

print("--- Stratégie : Le Meilleur Ratio ---")
# sac3, p3, v3 = remplir_besace(tresor_tri_ratio, capacite_besace)
# print(f"Butin : {v3} écus pour {p3} kg. Objets : {[o['nom'] for o in sac3]}\n")

# %% [markdown]
# ## 🏆 Défi Final : Bilan de l'Aventure
#
# **Question 2 :** Quelle stratégie s'est avérée la plus rentable pour ce trésor précis ?

# %% [markdown]
# **Question 3 :** Existe-t-il une autre combinaison d'objets (même non trouvée par les stratégies gloutonnes) qui respecterait la contrainte de 10 kg mais rapporterait ENCORE PLUS d'écus ? Cherchez "à la main" !
