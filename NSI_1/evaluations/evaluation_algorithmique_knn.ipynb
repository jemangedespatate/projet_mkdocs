# %% [markdown]
# <div style="padding:10px; border:solid 4px #c0392b; border-radius:10px; background-color:#fadbd8;">
# <table width="100%">
#   <tr>
#     <td width="10%" style="text-align:left; font-size:large;">⏱️</td>
#     <td style="text-align:center;">
#       <span style="font-size:xx-large; font-weight:bold; color:#78281f;">Évaluation Sommaire</span><br>
#       <span style="font-size:large; color:#78281f;">Dichotomie, Tris et k-Plus Proches Voisins</span>
#     </td>
#     <td width="10%" style="text-align:right; font-size:large;">🎯</td>
#   </tr>
# </table>
# <hr style="border:1px solid #c0392b;">
# <table width="100%">
#   <tr>
#     <td><b>Classe :</b> Première NSI</td>
#     <td><b>Thèmes :</b> Algorithmique & IA</td>
#     <td><b>Durée :</b> 2 heures</td>
#   </tr>
# </table>
# </div>

# %% [markdown]
# <h1><span class="title-number">0</span> Questions de cours</h1>

# %% [markdown]
# !!! question Question de cours 1 (Tris et Dichotomie)
# 1. Quel est le **pré-requis indispensable** pour pouvoir effectuer une recherche dichotomique sur une liste ?
# 2. Trier une grande liste coûte beaucoup de temps (complexité quadratique $O(N^2)$). **Est-il rentable de trier une liste une bonne fois pour toutes si c'est pour effectuer des milliers de recherches ensuite ?** Justifiez.
# 3. Si vous jouez au jeu du "Plus ou Moins" (trouver un nombre entre 1 et 1 000), combien de coups au maximum vous faut-il pour gagner en jouant de manière optimale (dichotomie) ?
# !!!

# %% [raw]
# 1. Le pré-requis indispensable est ...
# 2. Oui/Non, c'est rentable car ...
# 3. Il faut au maximum ... coups.

# %% [markdown]
# !!! question Question de cours 2 (K-Plus Proches Voisins)
# Dans l'algorithme des k-Plus Proches Voisins, un problème algorithmique risque de survenir si l'on choisit une valeur de **k paire** (par exemple k=2).
# 1. Quel est ce problème ?
# 2. Que fait-on habituellement pour parer à cette éventualité ?
# !!!

# %% [raw]
# 1. Le problème qui risque de survenir est ...
# 2. Pour parer à cette éventualité, on ...

# %% [markdown]
# <h1><span class="title-number">I</span> Recherche Dichotomique & Complexité</h1>

# %% [markdown]
# On dispose d'une liste triée de codes d'accès sécurisés.
# Pour trouver un code, on hésite entre le **Scan Linéaire** et la **Recherche Dichotomique**.
#
# !!! question Question 1
# Implémentez la fonction `recherche_dichotomique(liste, cible)` en utilisant une boucle `while` (pas de récursivité).
# La fonction renverra `True` si la cible est présente, et `False` sinon.
# !!!

# %%
def recherche_dichotomique(liste, cible):
    # A FAIRE : Programmation de la recherche dichotomique
    pass

# ── Tests ────────────────────────────────────────────────────────────────────
codes = [12, 45, 67, 89, 102, 145, 178, 203, 256]
print("Recherche de 145 (attendu True) :", recherche_dichotomique(codes, 145))
print("Recherche de 150 (attendu False) :", recherche_dichotomique(codes, 150))

# %% [markdown]
# !!! question Question 2
# Notre base de données contient exactement **4 000 000** (4 millions) de codes.
# 1. Dans le pire des cas, combien de comparaisons (environ) le scan linéaire va-t-il faire ?
# 2. Dans le pire des cas, combien de comparaisons la recherche dichotomique fera-t-elle au maximum ?
# *(Rappel : on divise par 2 à chaque étape)*
# !!!

# %% [raw]
# 1. Le scan linéaire va faire ... comparaisons.
# 2. La dichotomie fera au maximum ... comparaisons, car ...

# %% [markdown]
# <h1><span class="title-number">II</span> Algorithmes de Tri</h1>

# %% [markdown]
# !!! question Question 3
# On souhaite trier la liste suivante par **ordre croissant** en utilisant le **Tri par Sélection** :
# `L = [15, 8, 23, 4, 10]`
#
# Donner l'état de la liste après le 1er tour de boucle, puis après le 2ème tour de boucle.
# !!!

# %% [raw]
# État initial : [15, 8, 23, 4, 10]
# Après le 1er passage (1er plus petit placé) : ...
# Après le 2ème passage : ...

# %% [markdown]
# !!! question Question 4
# Implémentez l'algorithme complet du **Tri par Insertion** dans la cellule ci-dessous.
# La fonction triera la liste directement sur place.
# !!!

# %%
def tri_insertion(L):
    # A FAIRE : implémentation du tri par insertion
    pass

# ── Tests ────────────────────────────────────────────────────────────────────
ma_liste = [42, 17, 8, 99, 23, 4]
tri_insertion(ma_liste)
print("Liste triée :", ma_liste)

# %% [markdown]
# !!! question Question 5
# Implémentez l'algorithme complet du **Tri par Sélection** dans la cellule ci-dessous.
# La fonction la liste directement sur place (trie la liste sans renvoyer de nouvelle liste).
# !!!

# %%
def tri_selection(L):
    # A FAIRE : implémentation du tri par sélection
    pass

# ── Tests ────────────────────────────────────────────────────────────────────
ma_liste_2 = [23, 12, 5, 89, 4, 30]
tri_selection(ma_liste_2)
print("Liste triée avec sélection :", ma_liste_2)

# %% [markdown]
# <h1><span class="title-number">III</span> Apprentissage IA : k-Plus Proches Voisins (k-NN)</h1>

# %% [markdown]
# Nous avons une base de données de personnages (Joueur contre Joueur).
# Chaque personnage possède une **Attaque Physique** (de 1 à 10) et une **Attaque Magique** (de 1 à 10).
# Il a aussi une `classe` : **'Guerrier'** ou **'Mage'**.

# %%
personnages = [
    {'physique': 8, 'magique': 2, 'classe': 'Guerrier'},
    {'physique': 2, 'magique': 9, 'classe': 'Mage'},
    {'physique': 6, 'magique': 4, 'classe': 'Guerrier'},
    {'physique': 3, 'magique': 7, 'classe': 'Mage'},
    {'physique': 5, 'magique': 5, 'classe': 'Guerrier'},
    {'physique': 4, 'magique': 8, 'classe': 'Mage'}
]

# %% [markdown]
# !!! question Question 6
# Complétez la fonction `distance(p1, p2)` qui calcule la **distance au carré** entre deux personnages.
# !!!

# %%
def distance_carre(p1, p2):
    pass

# ── Tests ────────────────────────────────────────────────────────────────────
print("Distance entre P0 et P1 :", distance_carre(personnages[0], personnages[1]))

# %% [markdown]
# !!! question Question 7
# Un Profil Inconnu (PNJ) surgit dans le jeu :
# `pnj = {'physique': 4, 'magique': 6}`
#
# Complétez la fonction `knn_predict` qui :
# 1. Calcule la distance de `pnj` avec tous les `personnages` connus.
# 2. Crée une liste de tuples `(distance, classe_du_personnage)`.
# 3. Trie cette liste par ordre de distance croissante (utilisez `.sort()`).
# 4. Extrait les classes des `k` voisins les plus proches.
# !!!

# %%
def knn_predict(tableau_persos, pnj_inconnu, k):
    distances = []
    for p in tableau_persos:
        d = distance_carre(p, pnj_inconnu)
        # A FAIRE : Insérer le tuple (d, classe_de_p) dans distances
    
    # A FAIRE : Trier la liste `distances`
    
    
    voisins = []
    # A FAIRE : Parcourir les k premiers éléments et ajouter leur classe à `voisins`
    
        
    return voisins

# ── Tests ────────────────────────────────────────────────────────────────────
pnj_test = {'physique': 4, 'magique': 6}
print("Les 3 plus proches voisins :", knn_predict(personnages, pnj_test, 3))

# %% [markdown]
# !!! question Question 8
# En regardant le résultat produit par votre fonction pour $k=3$ :
# Le `pnj_test` sera classé Mage ou Guerrier par majorité ?
# Que se passerait-il si l'on choisissait $k=6$ (soit le nombre total de personnages de notre jeu) ? Y aurait-il un souci de vote ?
# !!!

# %% [raw]
# Pour k=3, il sera classé ... car ...
# Pour k=6, le problème est que ... car ...
